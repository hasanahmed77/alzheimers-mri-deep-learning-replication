# %%
import os
import sys
# reload modules to make sure Python sees your updated function
import importlib
import src.dataset
import src.train

importlib.reload(src.dataset)
importlib.reload(src.train)

# Get project root relative to the notebook
project_root = os.path.abspath("..")  # one level up from /notebooks/
sys.path.append(project_root)


from src.train import train_model
from src.evaluate import calculate_metrics
from src.dataset import get_data_loaders

data_dir = "../data/"
train_loader, val_loader, test_loader, _ = get_data_loaders(data_dir, batch_size=64)

# Train the model
train_model(model_name="vgg16", data_dir=data_dir, epochs=30, batch_size=64, lr=0.003)

# Load best model weights
from src.model import create_model
import torch

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
model = create_model("vgg16").to(device)
model.load_state_dict(torch.load("../models/vgg16_best.pth", map_location=device))

# Evaluate and store metrics
calculate_metrics(model, test_loader)
# Out:
# Using device: mps
# /Users/mustakimahmedhasan/Workspace/Research/Code/Alzheimer's Experiment/.venv/lib/python3.14/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/mustakimahmedhasan/Workspace/Research/Code/Alzheimer's Experiment/.venv/lib/python3.14/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /Users/mustakimahmedhasan/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100.0%
# Epoch 1/30 | Loss: 2.8129 | Val Acc: 0.6166
# ...
